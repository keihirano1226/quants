# %%
import os
import pickle
import sys
import warnings
from glob import glob
import re
import datetime
import itertools
from pyti.moving_average_convergence_divergence import moving_average_convergence_divergence as macd
from pyti.simple_moving_average import simple_moving_average as sma
from pyti.stochastic import percent_k as srv_k
from pyti.stochastic import percent_d as srv_d
from tqdm import tqdm
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.dates import date2num, DayLocator, DateFormatter
#from mpl_finance import candlestick2_ohlc, volume_overlay
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
import lightgbm
import talib

# %%
dataset_dir="../data_dir/"

# %%
# 読み込むファイルを定義します。
inputs = {
    "stock_list": f"{dataset_dir}/stock_list.csv",
    "stock_price": f"{dataset_dir}/stock_price.csv",
    "stock_fin": f"{dataset_dir}/stock_fin.csv",
    # 本チュートリアルでは使用しないため、コメントアウトしています。
    # "stock_fin_price": f"{dataset_dir}/stock_fin_price.csv.gz",
    "stock_labels": f"{dataset_dir}/stock_labels.csv",
    "stock_fin_growth_rate": f"{dataset_dir}/stock_fin_growth_rate.csv",
    "train_X": f"{dataset_dir}/train_X.csv",
}

# ファイルを読み込みます
dfs = {}
for k, v in inputs.items():
    print(k)
    dfs[k] = pd.read_csv(v)
    # DataFrameのindexを設定します。
    if k == "stock_price":
        dfs[k].loc[:, "datetime"] = pd.to_datetime(
            dfs[k].loc[:, "EndOfDayQuote Date"]
        )
        dfs[k].set_index("datetime", inplace=True)
    elif k in ["stock_fin", "stock_fin_price", "stock_labels"]:
        dfs[k].loc[:, "datetime"] = pd.to_datetime(
            dfs[k].loc[:, "base_date"]
        )
        dfs[k].set_index("datetime", inplace=True)
# Out:
# stock_list
# stock_price
# stock_fin
# stock_labels
# stock_fin_growth_rate
# train_X

# %%
def cross_X(x):
    return np.prod(x)

def get_features_for_predict(dfs, code, start_dt="2016-01-01"):
    """
    Args:
        dfs (dict)  : dict of pd.DataFrame include stock_fin, stock_price
        code (int)  : A local code for a listed company
        start_dt (str): specify date range
    Returns:
        feature DataFrame (pd.DataFrame)
    """
    # おおまかな手順の1つ目
    # stock_finデータを読み込み
    stock_fin = dfs["stock_fin"]
    periods = [10, 20, 40]
    # 特定の銘柄コードのデータに絞る
    stock_fin = stock_fin[stock_fin["Local Code"] == code]
    fin_data = stock_fin[~stock_fin.duplicated(subset=['Local Code', 'Result_FinancialStatement ReportType',"Result_FinancialStatement FiscalYear"],keep='last')]
    # 特徴量の作成には過去60営業日のデータを使用しているため、
    # 予測対象日からバッファ含めて土日を除く過去90日遡った時点から特徴量を生成します
    n = 90
    # 特徴量の生成対象期間を指定
    
    fin_data = fin_data.loc[pd.Timestamp(start_dt) - pd.offsets.BDay(n) :]
    seasons = stock_fin["Result_FinancialStatement ReportType"].unique()
    columns = fin_data.columns
    columns = columns.to_list()
    columns_list = ["Result_FinancialStatement NetSales","Result_FinancialStatement OrdinaryIncome","Result_FinancialStatement TotalAssets","Result_FinancialStatement NetAssets"]
    for column in columns_list:
        a = "last "+column
        print(a)
        print(type(columns))
        columns.append(a)
    df_result = pd.DataFrame(index=[], columns=columns)
    # columns_list.append("base_date")
    # columns_list.append("Local Code")
    for season in seasons:
        #df["last "+column] = 0
        #print(columns_list)
        df_test = fin_data[fin_data["Result_FinancialStatement ReportType"]==season].copy()
        for column in columns_list:
            #print(columns)
            df_test["last "+column] = df_test[column]
            df_test["last "+column] = df_test[column].shift()
            #df = pd.merge(df,df_test[["last "+column,"base_date","Local Code"]],on = ["base_date","Local Code"],how="left")
            #df_ab, df_ac, on='a', how='left'
        #print(df_result)
        #print(df_test)
        df_result = pd.concat([df_result,df_test])
    df_result["NetSales_growth_rate"] = df_result["Result_FinancialStatement NetSales"] / df_result["last Result_FinancialStatement NetSales"]
    df_result["OrdinaryIncome_growth_rate"] = df_result["Result_FinancialStatement OrdinaryIncome"] / df_result["last Result_FinancialStatement OrdinaryIncome"]
    df_result["TotalAssets_growth_rate"] = df_result["Result_FinancialStatement TotalAssets"] / df_result["last Result_FinancialStatement TotalAssets"]
    df_result["NetAssets_growth_rate"] = df_result["Result_FinancialStatement NetAssets"] / df_result["last Result_FinancialStatement NetAssets"]
    #df_result = df_result.drop(["EndOfDayQuote ExchangeOfficialClose","macd_hist_shift","stocas_hist_shift","stocas_huge_signal"], axis=1)
#     # fin_dataのnp.float64のデータのみを取得
#     fin_data = fin_data.select_dtypes(include=["float64"])
#     # 欠損値処理
#     fin_feats = fin_data.fillna(0)

    # おおまかな手順の2つ目
    # stock_priceデータを読み込む
    price = dfs["stock_price"]
    # 特定の銘柄コードのデータに絞る
    price_data = price[price["Local Code"] == code]
    # 終値のみに絞る
    feats = price_data[["EndOfDayQuote ExchangeOfficialClose"]]
    # 特徴量の生成対象期間を指定
    feats = feats.loc[pd.Timestamp(start_dt) - pd.offsets.BDay(n) :].copy()

    # 終値の20営業日リターン
    feats["return_1month"] = feats["EndOfDayQuote ExchangeOfficialClose"].pct_change(20)
    # 終値の40営業日リターン
    feats["return_2month"] = feats["EndOfDayQuote ExchangeOfficialClose"].pct_change(40)
    # 終値の60営業日リターン
    feats["return_3month"] = feats["EndOfDayQuote ExchangeOfficialClose"].pct_change(60)
    # 終値の20営業日ボラティリティ
    feats["volatility_0.5month"] = (
        np.log(feats["EndOfDayQuote ExchangeOfficialClose"]).diff().rolling(10).std()
    )
    # 終値の40営業日ボラティリティ
    feats["volatility_1month"] = (
        np.log(feats["EndOfDayQuote ExchangeOfficialClose"]).diff().rolling(20).std()
    )
    # 終値の60営業日ボラティリティ
    feats["volatility_2month"] = (
        np.log(feats["EndOfDayQuote ExchangeOfficialClose"]).diff().rolling(40).std()
    )
    
    for period in periods:
        col = "5 windows volatility  {} mean".format(period)
        feats[col] = feats["volatility_0.5month"].rolling(period).mean()
    
    # ヒストリカル・ボラティリティ移動平均
    for period in periods:
        col = "25 windows volatility  {} mean".format(period)
        feats[col] = feats["volatility_1month"].rolling(period).mean()
        
    # ヒストリカル・ボラティリティ移動平均
    for period in periods:
        col = "75 windows volatility  {} mean".format(period)
        feats[col] = feats["volatility_2month"].rolling(period).mean()

    # ヒストリカル・ボラティリティ移動平均微分値
    for period in periods:
        col = "5 windows volatility  {} mean diff".format(period)
        feats[col] = feats["volatility_0.5month"].rolling(10).mean().pct_change(period)

    # ヒストリカル・ボラティリティ移動平均微分値
    for period in periods:
        col = "25 windows volatility  {} mean diff".format(period)
        feats[col] = feats["volatility_1month"].rolling(20).mean().pct_change(period)

    # ヒストリカル・ボラティリティ移動平均微分値
    for period in periods:
        col = "75 windows volatility  {} mean diff".format(period)
        feats[col] = feats["volatility_2month"].rolling(30).mean().pct_change(period)
    
    macd_period = {'long' : 26, 'short' : 12}
    sma_period  = 9
    feats['macd'] = macd(feats['EndOfDayQuote ExchangeOfficialClose'].values.tolist(), 12, 26)
    feats['macd_signal'] = sma(feats['macd'].values.tolist(), sma_period)
    feats["macd_hist"] = feats["macd"] - feats["macd_signal"]
    feats["macd_hist_shift"] = feats["macd_hist"].shift()
    feats.loc[feats["macd_hist"] < 0,"macd_hist_signal"] = -1
    feats.loc[feats["macd_hist"] > 0,"macd_hist_signal"] = 1
    feats.loc[feats["macd_hist"] == 0,"macd_hist_signal"] = 0
    feats["macd_cross_signal"] = feats["macd_hist"]*feats["macd_hist_shift"]
    feats.loc[feats["macd_cross_signal"] <= 0, "macd_cross_signal"] = 0
    feats.loc[feats["macd_cross_signal"] > 0, "macd_cross_signal"] = 1
    feats["macd_cross_sign_20"] = (1-feats["macd_cross_signal"].rolling(20).apply(cross_X))*feats["macd_hist_signal"]
    feats["macd_cross_sign_10"] = (1-feats["macd_cross_signal"].rolling(10).apply(cross_X))*feats["macd_hist_signal"]
    feats["macd_cross_sign_5"] = (1-feats["macd_cross_signal"].rolling(5).apply(cross_X))*feats["macd_hist_signal"]
    #feats.loc[feats["macd_cross_sign"] > 0, "macd_cross_sign"] = 1
    mac_cols = ["macd","macd_signal","macd_hist"]
    mac_cross_cols = ["macd_cross_sign_20","macd_cross_sign_10"]
    feats["slow%k"] = srv_d(feats["EndOfDayQuote ExchangeOfficialClose"].values.tolist(), 14)*100
    feats["slow%d"] = feats["slow%k"].rolling(3).mean()
    feats["stocas_hist"] = feats["slow%k"] - feats["slow%d"]
    feats["stocas_hist_shift"] = feats["stocas_hist"].shift()
    feats["stocas_cross_signal"] = feats["stocas_hist"]*feats["stocas_hist_shift"]
    feats.loc[feats["stocas_cross_signal"] <= 0, "stocas_cross_signal"] = 0
    feats.loc[feats["stocas_cross_signal"] > 0, "stocas_cross_signal"] = 1
    feats.loc[feats["stocas_hist"] < 0,"stocas_hist_signal"] = -1
    feats.loc[feats["stocas_hist"] > 0,"stocas_hist_signal"] = 1
    feats.loc[feats["stocas_hist"] == 0,"stocas_hist_signal"] = 0
    feats["stocas_huge_signal"] = 0
    feats.loc[feats["slow%k"] <= 20,"stocas_huge_signal"] = 1
    feats.loc[feats["slow%k"] >= 80,"stocas_huge_signal"] = 1
    # feats["stocas_cross_sign_20"] = (1-feats["stocas_cross_signal"].rolling(20).apply(cross_X))*feats["stocas_hist_signal"]*feats["stocas_huge_signal"]
    # feats["stocas_cross_sign_10"] = (1-feats["stocas_cross_signal"].rolling(10).apply(cross_X))*feats["stocas_hist_signal"]*feats["stocas_huge_signal"]
    feats["stocas_cross_sign_5"] = (1-feats["stocas_cross_signal"].rolling(5).apply(cross_X))*feats["stocas_hist_signal"]*feats["stocas_huge_signal"]
    
    
    # おおまかな手順の3つ目
    # 欠損値処理
    #feats = feats.fillna(0)
    # 元データのカラムを削除
    feats = feats.drop(["EndOfDayQuote ExchangeOfficialClose","macd_hist_shift","stocas_hist_shift","stocas_huge_signal"], axis=1)

    #財務データの特徴量とマーケットデータの特徴量のインデックスを合わせる
    feats = feats.loc[feats.index.isin(df_result.index)]
    df_result = df_result.loc[df_result.index.isin(feats.index)]
    print(df_result.head())
    print(feats.head())
    #feats = pd.concat([feats, df_result], axis=1).dropna()
    # データを結合
    #print(feats.index)
    feats = pd.merge(df_result,feats,left_index= True,right_index = True ,how = "left")
    

    # 欠損値処理を行います。
    feats = feats.replace([np.inf, -np.inf], 0)

    # 銘柄コードを設定
    feats["code"] = code


    return feats

# %%
df = get_features_for_predict(dfs, 9984)
df.T
# Out:
# last Result_FinancialStatement NetSales
# <class 'list'>
# last Result_FinancialStatement OrdinaryIncome
# <class 'list'>
# last Result_FinancialStatement TotalAssets
# <class 'list'>
# last Result_FinancialStatement NetAssets
# <class 'list'>
#              base_date Local Code  \
# 2016-04-21  2016/04/21       9984
# 2017-02-08  2017/02/08       9984
# 2018-02-07  2018/02/07       9984
# 2019-02-06  2019/02/06       9984
# 2020-04-30  2020/04/30       9984
#
#            Result_FinancialStatement AccountingStandard  \
# 2016-04-21                             ConsolidatedIFRS
# 2017-02-08                             ConsolidatedIFRS
# 2018-02-07                             ConsolidatedIFRS
# 2019-02-06                             ConsolidatedIFRS
# 2020-04-30                             ConsolidatedIFRS
#
#            Result_FinancialStatement FiscalPeriodEnd  \
# 2016-04-21                                   2015/12
# 2017-02-08                                   2016/12
# 2018-02-07                                   2017/12
# 2019-02-06                                   2018/12
# 2020-04-30                                   2019/12
#
#            Result_FinancialStatement ReportType  \
# 2016-04-21                                   Q3
# 2017-02-08                                   Q3
# 2018-02-07                                   Q3
# 2019-02-06                                   Q3
# 2020-04-30                                   Q3
#
#             Result_FinancialStatement FiscalYear  \
# 2016-04-21                                2016.0
# 2017-02-08                                2017.0
# 2018-02-07                                2018.0
# 2019-02-06                                2019.0
# 2020-04-30                                2020.0
#
#            Result_FinancialStatement ModifyDate  \
# 2016-04-21                           2016/02/10
# 2017-02-08                           2017/02/08
# 2018-02-07                           2018/02/07
# 2019-02-06                           2019/02/06
# 2020-04-30                           2020/02/12
#
#            Result_FinancialStatement CompanyType  \
# 2016-04-21                                    GB
# 2017-02-08                                    GB
# 2018-02-07                                    GB
# 2019-02-06                                    GB
# 2020-04-30                                    GB
#
#            Result_FinancialStatement ChangeOfFiscalYearEnd  \
# 2016-04-21                                           False
# 2017-02-08                                           False
# 2018-02-07                                           False
# 2019-02-06                                           False
# 2020-04-30                                           False
#
#             Result_FinancialStatement NetSales  ...  \
# 2016-04-21                           6810206.0  ...
# 2017-02-08                           6581466.0  ...
# 2018-02-07                           6811274.0  ...
# 2019-02-06                           7168452.0  ...
# 2020-04-30                           7089804.0  ...
#
#             Forecast_Dividend QuarterlyDividendPerShare  \
# 2016-04-21                                         21.0
# 2017-02-08                                         22.0
# 2018-02-07                                         22.0
# 2019-02-06                                         22.0
# 2020-04-30                                         22.0
#
#             Forecast_Dividend AnnualDividendPerShare  \
# 2016-04-21                                      41.0
# 2017-02-08                                      44.0
# 2018-02-07                                      44.0
# 2019-02-06                                      44.0
# 2020-04-30                                      44.0
#
#             last Result_FinancialStatement NetSales  \
# 2016-04-21                                      NaN
# 2017-02-08                                6810206.0
# 2018-02-07                                6581466.0
# 2019-02-06                                6811274.0
# 2020-04-30                                7168452.0
#
#             last Result_FinancialStatement OrdinaryIncome  \
# 2016-04-21                                            NaN
# 2017-02-08                                       918214.0
# 2018-02-07                                       975257.0
# 2019-02-06                                       563804.0
# 2020-04-30                                      1809834.0
#
#             last Result_FinancialStatement TotalAssets  \
# 2016-04-21                                         NaN
# 2017-02-08                                  21497648.0
# 2018-02-07                                  24867038.0
# 2019-02-06                                  29412718.0
# 2020-04-30                                  36459477.0
#
#             last Result_FinancialStatement NetAssets  NetSales_growth_rate  \
# 2016-04-21                                       NaN                   NaN
# 2017-02-08                                 3855507.0              0.966412
# 2018-02-07                                 3981711.0              1.034917
# 2019-02-06                                 6568877.0              1.052439
# 2020-04-30                                 9286389.0              0.989029
#
#             OrdinaryIncome_growth_rate TotalAssets_growth_rate  \
# 2016-04-21                         NaN                     NaN
# 2017-02-08                    1.062124                1.156733
# 2018-02-07                    0.578108                1.182799
# 2019-02-06                    3.210041                1.239582
# 2020-04-30                    0.743371                1.080828
#
#            NetAssets_growth_rate
# 2016-04-21                   NaN
# 2017-02-08              1.032733
# 2018-02-07              1.649762
# 2019-02-06              1.413695
# 2020-04-30              0.989773
#
# [5 rows x 52 columns]
#             return_1month  return_2month  return_3month  volatility_0.5month  \
# datetime
# 2016-04-21       0.089088       0.144146       0.255517             0.021859
# 2016-05-10       0.086886       0.024098       0.173981             0.023792
# 2016-07-28      -0.076102      -0.141715      -0.103874             0.038998
# 2016-11-07      -0.039686      -0.077414       0.060667             0.014273
# 2017-02-08       0.022248       0.114476       0.441806             0.015944
#
#             volatility_1month  volatility_2month  \
# datetime
# 2016-04-21           0.017177           0.017050
# 2016-05-10           0.022711           0.018186
# 2016-07-28           0.031758           0.030624
# 2016-11-07           0.018166           0.017174
# 2017-02-08           0.015226           0.014092
#
#             5 windows volatility  10 mean  5 windows volatility  20 mean  \
# datetime
# 2016-04-21                       0.014255                       0.011990
# 2016-05-10                       0.023818                       0.018466
# 2016-07-28                       0.038075                       0.034558
# 2016-11-07                       0.014174                       0.017547
# 2017-02-08                       0.017379                       0.015954
#
#             5 windows volatility  40 mean  25 windows volatility  10 mean  \
# datetime
# 2016-04-21                       0.017737                        0.013845
# 2016-05-10                       0.015694                        0.019527
# 2016-07-28                       0.029114                        0.034528
# 2016-11-07                       0.016850                        0.017706
# 2017-02-08                       0.017002                        0.015662
#
#             ...  macd_cross_signal  macd_cross_sign_20  macd_cross_sign_10  \
# datetime    ...
# 2016-04-21  ...                1.0                 1.0                 1.0
# 2016-05-10  ...                1.0                -1.0                -1.0
# 2016-07-28  ...                1.0                -1.0                -1.0
# 2016-11-07  ...                1.0                -1.0                -1.0
# 2017-02-08  ...                1.0                -1.0                -1.0
#
#             macd_cross_sign_5     slow%k     slow%d  stocas_hist  \
# datetime
# 2016-04-21                0.0  98.410608  89.883737     8.526871
# 2016-05-10               -1.0  20.149683  17.259363     2.890321
# 2016-07-28               -0.0  21.576064  14.557930     7.018134
# 2016-11-07               -0.0   9.945610  11.917354    -1.971744
# 2017-02-08               -1.0  52.845724  52.647314     0.198410
#
#             stocas_cross_signal  stocas_hist_signal  stocas_cross_sign_5
# datetime
# 2016-04-21                  0.0                 1.0                  1.0
# 2016-05-10                  0.0                 1.0                  0.0
# 2016-07-28                  1.0                 1.0                  0.0
# 2016-11-07                  1.0                -1.0                 -1.0
# 2017-02-08                  0.0                 1.0                  0.0
#
# [5 rows x 38 columns]
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:131: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:132: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:133: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:152: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#                                                           2016-04-21  \
# base_date                                                 2016/04/21
# Local Code                                                      9984
# Result_FinancialStatement AccountingStandard        ConsolidatedIFRS
# Result_FinancialStatement FiscalPeriodEnd                    2015/12
# Result_FinancialStatement ReportType                              Q3
# Result_FinancialStatement FiscalYear                            2016
# Result_FinancialStatement ModifyDate                      2016/02/10
# Result_FinancialStatement CompanyType                             GB
# Result_FinancialStatement ChangeOfFiscalYearEnd                False
# Result_FinancialStatement NetSales                       6.81021e+06
# Result_FinancialStatement OperatingIncome                     875322
# Result_FinancialStatement OrdinaryIncome                      918214
# Result_FinancialStatement NetIncome                           428972
# Result_FinancialStatement TotalAssets                    2.14976e+07
# Result_FinancialStatement NetAssets                      3.85551e+06
# Result_FinancialStatement CashFlowsFromOperatin...               NaN
# Result_FinancialStatement CashFlowsFromFinancin...               NaN
# Result_FinancialStatement CashFlowsFromInvestin...               NaN
# Forecast_FinancialStatement AccountingStandard                   NaN
# Forecast_FinancialStatement FiscalPeriodEnd                      NaN
# Forecast_FinancialStatement ReportType                           NaN
# Forecast_FinancialStatement FiscalYear                           NaN
# Forecast_FinancialStatement ModifyDate                           NaN
# Forecast_FinancialStatement CompanyType                          NaN
# Forecast_FinancialStatement ChangeOfFiscalYearEnd                NaN
# Forecast_FinancialStatement NetSales                             NaN
# Forecast_FinancialStatement OperatingIncome                      NaN
# Forecast_FinancialStatement OrdinaryIncome                       NaN
# Forecast_FinancialStatement NetIncome                            NaN
# Result_Dividend FiscalPeriodEnd                                  NaN
# ...                                                              ...
# 25 windows volatility  10 mean                             0.0138452
# 25 windows volatility  20 mean                             0.0134488
# 25 windows volatility  40 mean                             0.0262219
# 75 windows volatility  10 mean                             0.0213585
# 75 windows volatility  20 mean                             0.0295027
# 75 windows volatility  40 mean                                     0
# 5 windows volatility  10 mean diff                          0.466031
# 5 windows volatility  20 mean diff                        -0.0607215
# 5 windows volatility  40 mean diff                         -0.771943
# 25 windows volatility  10 mean diff                        -0.311284
# 25 windows volatility  20 mean diff                        -0.655114
# 25 windows volatility  40 mean diff                                0
# 75 windows volatility  10 mean diff                                0
# 75 windows volatility  20 mean diff                                0
# 75 windows volatility  40 mean diff                                0
# macd                                                         74.4632
# macd_signal                                                  32.4068
# macd_hist                                                    42.0564
# macd_hist_signal                                                   1
# macd_cross_signal                                                  1
# macd_cross_sign_20                                                 1
# macd_cross_sign_10                                                 1
# macd_cross_sign_5                                                  0
# slow%k                                                       98.4106
# slow%d                                                       89.8837
# stocas_hist                                                  8.52687
# stocas_cross_signal                                                0
# stocas_hist_signal                                                 1
# stocas_cross_sign_5                                                1
# code                                                            9984
#
#                                                           2017-02-08  \
# base_date                                                 2017/02/08
# Local Code                                                      9984
# Result_FinancialStatement AccountingStandard        ConsolidatedIFRS
# Result_FinancialStatement FiscalPeriodEnd                    2016/12
# Result_FinancialStatement ReportType                              Q3
# Result_FinancialStatement FiscalYear                            2017
# Result_FinancialStatement ModifyDate                      2017/02/08
# Result_FinancialStatement CompanyType                             GB
# Result_FinancialStatement ChangeOfFiscalYearEnd                False
# Result_FinancialStatement NetSales                       6.58147e+06
# Result_FinancialStatement OperatingIncome                     949660
# Result_FinancialStatement OrdinaryIncome                      975257
# Result_FinancialStatement NetIncome                           857431
# Result_FinancialStatement TotalAssets                     2.4867e+07
# Result_FinancialStatement NetAssets                      3.98171e+06
# Result_FinancialStatement CashFlowsFromOperatin...               NaN
# Result_FinancialStatement CashFlowsFromFinancin...               NaN
# Result_FinancialStatement CashFlowsFromInvestin...               NaN
# Forecast_FinancialStatement AccountingStandard                   NaN
# Forecast_FinancialStatement FiscalPeriodEnd                      NaN
# Forecast_FinancialStatement ReportType                           NaN
# Forecast_FinancialStatement FiscalYear                           NaN
# Forecast_FinancialStatement ModifyDate                           NaN
# Forecast_FinancialStatement CompanyType                          NaN
# Forecast_FinancialStatement ChangeOfFiscalYearEnd                NaN
# Forecast_FinancialStatement NetSales                             NaN
# Forecast_FinancialStatement OperatingIncome                      NaN
# Forecast_FinancialStatement OrdinaryIncome                       NaN
# Forecast_FinancialStatement NetIncome                            NaN
# Result_Dividend FiscalPeriodEnd                              2016/09
# ...                                                              ...
# 25 windows volatility  10 mean                             0.0156615
# 25 windows volatility  20 mean                             0.0146699
# 25 windows volatility  40 mean                             0.0173339
# 75 windows volatility  10 mean                             0.0176092
# 75 windows volatility  20 mean                             0.0174931
# 75 windows volatility  40 mean                             0.0209722
# 5 windows volatility  10 mean diff                          0.196115
# 5 windows volatility  20 mean diff                          0.372557
# 5 windows volatility  40 mean diff                          0.190048
# 25 windows volatility  10 mean diff                        -0.115901
# 25 windows volatility  20 mean diff                         -0.26643
# 25 windows volatility  40 mean diff                        -0.481781
# 75 windows volatility  10 mean diff                        -0.107647
# 75 windows volatility  20 mean diff                        -0.184785
# 75 windows volatility  40 mean diff                       -0.0863656
# macd                                                         53.4816
# macd_signal                                                  83.5491
# macd_hist                                                   -30.0675
# macd_hist_signal                                                  -1
# macd_cross_signal                                                  1
# macd_cross_sign_20                                                -1
# macd_cross_sign_10                                                -1
# macd_cross_sign_5                                                 -1
# slow%k                                                       52.8457
# slow%d                                                       52.6473
# stocas_hist                                                  0.19841
# stocas_cross_signal                                                0
# stocas_hist_signal                                                 1
# stocas_cross_sign_5                                                0
# code                                                            9984
#
#                                                           2018-02-07  \
# base_date                                                 2018/02/07
# Local Code                                                      9984
# Result_FinancialStatement AccountingStandard        ConsolidatedIFRS
# Result_FinancialStatement FiscalPeriodEnd                    2017/12
# Result_FinancialStatement ReportType                              Q3
# Result_FinancialStatement FiscalYear                            2018
# Result_FinancialStatement ModifyDate                      2018/02/07
# Result_FinancialStatement CompanyType                             GB
# Result_FinancialStatement ChangeOfFiscalYearEnd                False
# Result_FinancialStatement NetSales                       6.81127e+06
# Result_FinancialStatement OperatingIncome                1.14883e+06
# Result_FinancialStatement OrdinaryIncome                      563804
# Result_FinancialStatement NetIncome                      1.01494e+06
# Result_FinancialStatement TotalAssets                    2.94127e+07
# Result_FinancialStatement NetAssets                      6.56888e+06
# Result_FinancialStatement CashFlowsFromOperatin...               NaN
# Result_FinancialStatement CashFlowsFromFinancin...               NaN
# Result_FinancialStatement CashFlowsFromInvestin...               NaN
# Forecast_FinancialStatement AccountingStandard                   NaN
# Forecast_FinancialStatement FiscalPeriodEnd                      NaN
# Forecast_FinancialStatement ReportType                           NaN
# Forecast_FinancialStatement FiscalYear                           NaN
# Forecast_FinancialStatement ModifyDate                           NaN
# Forecast_FinancialStatement CompanyType                          NaN
# Forecast_FinancialStatement ChangeOfFiscalYearEnd                NaN
# Forecast_FinancialStatement NetSales                             NaN
# Forecast_FinancialStatement OperatingIncome                      NaN
# Forecast_FinancialStatement OrdinaryIncome                       NaN
# Forecast_FinancialStatement NetIncome                            NaN
# Result_Dividend FiscalPeriodEnd                              2017/09
# ...                                                              ...
# 25 windows volatility  10 mean                             0.0160842
# 25 windows volatility  20 mean                             0.0155427
# 25 windows volatility  40 mean                             0.0143112
# 75 windows volatility  10 mean                             0.0145252
# 75 windows volatility  20 mean                             0.0143531
# 75 windows volatility  40 mean                             0.0144991
# 5 windows volatility  10 mean diff                         -0.191631
# 5 windows volatility  20 mean diff                          0.184315
# 5 windows volatility  40 mean diff                          0.035767
# 25 windows volatility  10 mean diff                         0.122198
# 25 windows volatility  20 mean diff                         0.188313
# 25 windows volatility  40 mean diff                       -0.0448544
# 75 windows volatility  10 mean diff                       -0.0172178
# 75 windows volatility  20 mean diff                       -0.0533668
# 75 windows volatility  40 mean diff                       -0.0880882
# macd                                                        -75.1804
# macd_signal                                                 -11.9186
# macd_hist                                                   -63.2618
# macd_hist_signal                                                  -1
# macd_cross_signal                                                  1
# macd_cross_sign_20                                                -1
# macd_cross_sign_10                                                -1
# macd_cross_sign_5                                                 -0
# slow%k                                                       9.76431
# slow%d                                                       5.64901
# stocas_hist                                                   4.1153
# stocas_cross_signal                                                0
# stocas_hist_signal                                                 1
# stocas_cross_sign_5                                                1
# code                                                            9984
#
#                                                           2019-02-06  \
# base_date                                                 2019/02/06
# Local Code                                                      9984
# Result_FinancialStatement AccountingStandard        ConsolidatedIFRS
# Result_FinancialStatement FiscalPeriodEnd                    2018/12
# Result_FinancialStatement ReportType                              Q3
# Result_FinancialStatement FiscalYear                            2019
# Result_FinancialStatement ModifyDate                      2019/02/06
# Result_FinancialStatement CompanyType                             GB
# Result_FinancialStatement ChangeOfFiscalYearEnd                False
# Result_FinancialStatement NetSales                       7.16845e+06
# Result_FinancialStatement OperatingIncome                1.85901e+06
# Result_FinancialStatement OrdinaryIncome                 1.80983e+06
# Result_FinancialStatement NetIncome                       1.5384e+06
# Result_FinancialStatement TotalAssets                    3.64595e+07
# Result_FinancialStatement NetAssets                      9.28639e+06
# Result_FinancialStatement CashFlowsFromOperatin...               NaN
# Result_FinancialStatement CashFlowsFromFinancin...               NaN
# Result_FinancialStatement CashFlowsFromInvestin...               NaN
# Forecast_FinancialStatement AccountingStandard                   NaN
# Forecast_FinancialStatement FiscalPeriodEnd                      NaN
# Forecast_FinancialStatement ReportType                           NaN
# Forecast_FinancialStatement FiscalYear                           NaN
# Forecast_FinancialStatement ModifyDate                           NaN
# Forecast_FinancialStatement CompanyType                          NaN
# Forecast_FinancialStatement ChangeOfFiscalYearEnd                NaN
# Forecast_FinancialStatement NetSales                             NaN
# Forecast_FinancialStatement OperatingIncome                      NaN
# Forecast_FinancialStatement OrdinaryIncome                       NaN
# Forecast_FinancialStatement NetIncome                            NaN
# Result_Dividend FiscalPeriodEnd                              2018/09
# ...                                                              ...
# 25 windows volatility  10 mean                             0.0239822
# 25 windows volatility  20 mean                              0.028841
# 25 windows volatility  40 mean                             0.0290092
# 75 windows volatility  10 mean                             0.0283561
# 75 windows volatility  20 mean                             0.0297317
# 75 windows volatility  40 mean                             0.0308402
# 5 windows volatility  10 mean diff                         -0.515255
# 5 windows volatility  20 mean diff                         -0.542671
# 5 windows volatility  40 mean diff                         -0.526378
# 25 windows volatility  10 mean diff                       -0.0915902
# 25 windows volatility  20 mean diff                        -0.011526
# 25 windows volatility  40 mean diff                        -0.153203
# 75 windows volatility  10 mean diff                       -0.0368467
# 75 windows volatility  20 mean diff                       -0.0702935
# 75 windows volatility  40 mean diff                       -0.0558024
# macd                                                         124.028
# macd_signal                                                  101.783
# macd_hist                                                    22.2455
# macd_hist_signal                                                   1
# macd_cross_signal                                                  1
# macd_cross_sign_20                                                 1
# macd_cross_sign_10                                                 0
# macd_cross_sign_5                                                  0
# slow%k                                                       89.0844
# slow%d                                                       90.7141
# stocas_hist                                                 -1.62974
# stocas_cross_signal                                                1
# stocas_hist_signal                                                -1
# stocas_cross_sign_5                                               -1
# code                                                            9984
#
#                                                           2020-04-30  \
# base_date                                                 2020/04/30
# Local Code                                                      9984
# Result_FinancialStatement AccountingStandard        ConsolidatedIFRS
# Result_FinancialStatement FiscalPeriodEnd                    2019/12
# Result_FinancialStatement ReportType                              Q3
# Result_FinancialStatement FiscalYear                            2020
# Result_FinancialStatement ModifyDate                      2020/02/12
# Result_FinancialStatement CompanyType                             GB
# Result_FinancialStatement ChangeOfFiscalYearEnd                False
# Result_FinancialStatement NetSales                        7.0898e+06
# Result_FinancialStatement OperatingIncome                     -12964
# Result_FinancialStatement OrdinaryIncome                 1.34538e+06
# Result_FinancialStatement NetIncome                           476587
# Result_FinancialStatement TotalAssets                    3.94064e+07
# Result_FinancialStatement NetAssets                      9.19142e+06
# Result_FinancialStatement CashFlowsFromOperatin...               NaN
# Result_FinancialStatement CashFlowsFromFinancin...               NaN
# Result_FinancialStatement CashFlowsFromInvestin...               NaN
# Forecast_FinancialStatement AccountingStandard      ConsolidatedIFRS
# Forecast_FinancialStatement FiscalPeriodEnd                  2020/03
# Forecast_FinancialStatement ReportType                        Annual
# Forecast_FinancialStatement FiscalYear                          2020
# Forecast_FinancialStatement ModifyDate                    2020/04/30
# Forecast_FinancialStatement CompanyType                           GB
# Forecast_FinancialStatement ChangeOfFiscalYearEnd              False
# Forecast_FinancialStatement NetSales                        6.15e+06
# Forecast_FinancialStatement OperatingIncome                -1.35e+06
# Forecast_FinancialStatement OrdinaryIncome                     20000
# Forecast_FinancialStatement NetIncome                        -900000
# Result_Dividend FiscalPeriodEnd                              2019/09
# ...                                                              ...
# 25 windows volatility  10 mean                             0.0473787
# 25 windows volatility  20 mean                             0.0678163
# 25 windows volatility  40 mean                             0.0639167
# 75 windows volatility  10 mean                             0.0681799
# 75 windows volatility  20 mean                             0.0685322
# 75 windows volatility  40 mean                             0.0591183
# 5 windows volatility  10 mean diff                         -0.348313
# 5 windows volatility  20 mean diff                         -0.649994
# 5 windows volatility  40 mean diff                         -0.120662
# 25 windows volatility  10 mean diff                        -0.186512
# 25 windows volatility  20 mean diff                         0.129948
# 25 windows volatility  40 mean diff                          1.02085
# 75 windows volatility  10 mean diff                         0.188907
# 75 windows volatility  20 mean diff                         0.532788
# 75 windows volatility  40 mean diff                          1.84431
# macd                                                         170.029
# macd_signal                                                  229.562
# macd_hist                                                   -59.5332
# macd_hist_signal                                                  -1
# macd_cross_signal                                                  1
# macd_cross_sign_20                                                -1
# macd_cross_sign_10                                                -1
# macd_cross_sign_5                                                 -1
# slow%k                                                        71.107
# slow%d                                                       62.1405
# stocas_hist                                                  8.96648
# stocas_cross_signal                                                1
# stocas_hist_signal                                                 1
# stocas_cross_sign_5                                                0
# code                                                            9984
#
#                                                           2016-05-10  \
# base_date                                                 2016/05/10
# Local Code                                                      9984
# Result_FinancialStatement AccountingStandard        ConsolidatedIFRS
# Result_FinancialStatement FiscalPeriodEnd                    2016/03
# Result_FinancialStatement ReportType                          Annual
# Result_FinancialStatement FiscalYear                            2016
# Result_FinancialStatement ModifyDate                      2016/05/10
# Result_FinancialStatement CompanyType                             GB
# Result_FinancialStatement ChangeOfFiscalYearEnd                False
# Result_FinancialStatement NetSales                       9.15355e+06
# Result_FinancialStatement OperatingIncome                     999488
# Result_FinancialStatement OrdinaryIncome                 1.00576e+06
# Result_FinancialStatement NetIncome                           474172
# Result_FinancialStatement TotalAssets                    2.07072e+07
# Result_FinancialStatement NetAssets                      3.50527e+06
# Result_FinancialStatement CashFlowsFromOperatin...            940186
# Result_FinancialStatement CashFlowsFromFinancin...             43270
# Result_FinancialStatement CashFlowsFromInvestin...      -1.65168e+06
# Forecast_FinancialStatement AccountingStandard                   NaN
# Forecast_FinancialStatement FiscalPeriodEnd                      NaN
# Forecast_FinancialStatement ReportType                           NaN
# Forecast_FinancialStatement FiscalYear                           NaN
# Forecast_FinancialStatement ModifyDate                           NaN
# Forecast_FinancialStatement CompanyType                          NaN
# Forecast_FinancialStatement ChangeOfFiscalYearEnd                NaN
# Forecast_FinancialStatement NetSales                             NaN
# Forecast_FinancialStatement OperatingIncome                      NaN
# Forecast_FinancialStatement OrdinaryIncome                       NaN
# Forecast_FinancialStatement NetIncome                            NaN
# Result_Dividend FiscalPeriodEnd                              2016/03
# ...                                                              ...
# 25 windows volatility  10 mean                             0.0195274
# 25 windows volatility  20 mean                             0.0164173
# 25 windows volatility  40 mean                             0.0188903
# 75 windows volatility  10 mean                             0.0170426
# 75 windows volatility  20 mean                             0.0201105
# 75 windows volatility  40 mean                             0.0306365
# 5 windows volatility  10 mean diff                          0.816128
# 5 windows volatility  20 mean diff                             1.377
# 5 windows volatility  40 mean diff                         -0.348566
# 25 windows volatility  10 mean diff                         0.220082
# 25 windows volatility  20 mean diff                        -0.231513
# 25 windows volatility  40 mean diff                         -0.69048
# 75 windows volatility  10 mean diff                        -0.257031
# 75 windows volatility  20 mean diff                                0
# 75 windows volatility  40 mean diff                                0
# macd                                                         30.5559
# macd_signal                                                   75.308
# macd_hist                                                   -44.7522
# macd_hist_signal                                                  -1
# macd_cross_signal                                                  1
# macd_cross_sign_20                                                -1
# macd_cross_sign_10                                                -1
# macd_cross_sign_5                                                 -1
# slow%k                                                       20.1497
# slow%d                                                       17.2594
# stocas_hist                                                  2.89032
# stocas_cross_signal                                                0
# stocas_hist_signal                                                 1
# stocas_cross_sign_5                                                0
# code                                                            9984
#
#                                                           2017-05-10  \
# base_date                                                 2017/05/10
# Local Code                                                      9984
# Result_FinancialStatement AccountingStandard        ConsolidatedIFRS
# Result_FinancialStatement FiscalPeriodEnd                    2017/03
# Result_FinancialStatement ReportType                          Annual
# Result_FinancialStatement FiscalYear                            2017
# Result_FinancialStatement ModifyDate                      2017/05/10
# Result_FinancialStatement CompanyType                             GB
# Result_FinancialStatement ChangeOfFiscalYearEnd                False
# Result_FinancialStatement NetSales                         8.901e+06
# Result_FinancialStatement OperatingIncome                  1.026e+06
# Result_FinancialStatement OrdinaryIncome                      712526
# Result_FinancialStatement NetIncome                      1.42631e+06
# Result_FinancialStatement TotalAssets                    2.46342e+07
# Result_FinancialStatement NetAssets                      4.46973e+06
# Result_FinancialStatement CashFlowsFromOperatin...       1.50073e+06
# Result_FinancialStatement CashFlowsFromFinancin...       2.38075e+06
# Result_FinancialStatement CashFlowsFromInvestin...       -4.2136e+06
# Forecast_FinancialStatement AccountingStandard                   NaN
# Forecast_FinancialStatement FiscalPeriodEnd                      NaN
# Forecast_FinancialStatement ReportType                           NaN
# Forecast_FinancialStatement FiscalYear                           NaN
# Forecast_FinancialStatement ModifyDate                           NaN
# Forecast_FinancialStatement CompanyType                          NaN
# Forecast_FinancialStatement ChangeOfFiscalYearEnd                NaN
# Forecast_FinancialStatement NetSales                             NaN
# Forecast_FinancialStatement OperatingIncome                      NaN
# Forecast_FinancialStatement OrdinaryIncome                       NaN
# Forecast_FinancialStatement NetIncome                            NaN
# Result_Dividend FiscalPeriodEnd                              2017/03
# ...                                                              ...
# 25 windows volatility  10 mean                             0.0128645
# 25 windows volatility  20 mean                             0.0133011
# 25 windows volatility  40 mean                             0.0130872
# 75 windows volatility  10 mean                             0.0130389
# 75 windows volatility  20 mean                              0.013215
# 75 windows volatility  40 mean                             0.0134675
# 5 windows volatility  10 mean diff                         -0.275604
# 5 windows volatility  20 mean diff                           -0.2674
# 5 windows volatility  40 mean diff                         -0.339023
# 25 windows volatility  10 mean diff                        0.0117469
# 25 windows volatility  20 mean diff                        0.0332313
# 25 windows volatility  40 mean diff                       -0.0925337
# 75 windows volatility  10 mean diff                       -0.0277257
# 75 windows volatility  20 mean diff                       -0.0648294
# 75 windows volatility  40 mean diff                        -0.149753
# macd                                                          118.19
# macd_signal                                                  76.0933
# macd_hist                                                    42.0966
# macd_hist_signal                                                   1
# macd_cross_signal                                                  1
# macd_cross_sign_20                                                 0
# macd_cross_sign_10                                                 0
# macd_cross_sign_5                                                  0
# slow%k                                                       98.6003
# slow%d                                                       99.0668
# stocas_hist                                                 -0.46658
# stocas_cross_signal                                                1
# stocas_hist_signal                                                -1
# stocas_cross_sign_5                                               -1
# code                                                            9984
#
#                                                           2018-05-09  \
# base_date                                                 2018/05/09
# Local Code                                                      9984
# Result_FinancialStatement AccountingStandard        ConsolidatedIFRS
# Result_FinancialStatement FiscalPeriodEnd                    2018/03
# Result_FinancialStatement ReportType                          Annual
# Result_FinancialStatement FiscalYear                            2018
# Result_FinancialStatement ModifyDate                      2018/05/09
# Result_FinancialStatement CompanyType                             GB
# Result_FinancialStatement ChangeOfFiscalYearEnd                False
# Result_FinancialStatement NetSales                       9.15876e+06
# Result_FinancialStatement OperatingIncome                 1.3038e+06
# Result_FinancialStatement OrdinaryIncome                      384630
# Result_FinancialStatement NetIncome                      1.03898e+06
# Result_FinancialStatement TotalAssets                    3.11805e+07
# Result_FinancialStatement NetAssets                      6.27302e+06
# Result_FinancialStatement CashFlowsFromOperatin...       1.08862e+06
# Result_FinancialStatement CashFlowsFromFinancin...       4.62642e+06
# Result_FinancialStatement CashFlowsFromInvestin...      -4.48482e+06
# Forecast_FinancialStatement AccountingStandard                   NaN
# Forecast_FinancialStatement FiscalPeriodEnd                      NaN
# Forecast_FinancialStatement ReportType                           NaN
# Forecast_FinancialStatement FiscalYear                           NaN
# Forecast_FinancialStatement ModifyDate                           NaN
# Forecast_FinancialStatement CompanyType                          NaN
# Forecast_FinancialStatement ChangeOfFiscalYearEnd                NaN
# Forecast_FinancialStatement NetSales                             NaN
# Forecast_FinancialStatement OperatingIncome                      NaN
# Forecast_FinancialStatement OrdinaryIncome                       NaN
# Forecast_FinancialStatement NetIncome                            NaN
# Result_Dividend FiscalPeriodEnd                              2018/03
# ...                                                              ...
# 25 windows volatility  10 mean                             0.0148493
# 25 windows volatility  20 mean                             0.0168051
# 25 windows volatility  40 mean                              0.016479
# 75 windows volatility  10 mean                             0.0166469
# 75 windows volatility  20 mean                             0.0167235
# 75 windows volatility  40 mean                             0.0171959
# 5 windows volatility  10 mean diff                        -0.0784054
# 5 windows volatility  20 mean diff                         -0.306021
# 5 windows volatility  40 mean diff                         -0.115782
# 25 windows volatility  10 mean diff                       -0.0735648
# 25 windows volatility  20 mean diff                        0.0403789
# 25 windows volatility  40 mean diff                        -0.130182
# 75 windows volatility  10 mean diff                      -0.00487079
# 75 windows volatility  20 mean diff                        -0.023108
# 75 windows volatility  40 mean diff                        0.0508541
# macd                                                         94.1222
# macd_signal                                                   77.109
# macd_hist                                                    17.0133
# macd_hist_signal                                                   1
# macd_cross_signal                                                  1
# macd_cross_sign_20                                                 1
# macd_cross_sign_10                                                 0
# macd_cross_sign_5                                                  0
# slow%k                                                       90.5735
# slow%d                                                          89.4
# stocas_hist                                                  1.17358
# stocas_cross_signal                                                0
# stocas_hist_signal                                                 1
# stocas_cross_sign_5                                                1
# code                                                            9984
#
#                                                           2019-05-09  \
# base_date                                                 2019/05/09
# Local Code                                                      9984
# Result_FinancialStatement AccountingStandard        ConsolidatedIFRS
# Result_FinancialStatement FiscalPeriodEnd                    2019/03
# Result_FinancialStatement ReportType                          Annual
# Result_FinancialStatement FiscalYear                            2019
# Result_FinancialStatement ModifyDate                      2019/05/09
# Result_FinancialStatement CompanyType                             GB
# Result_FinancialStatement ChangeOfFiscalYearEnd                False
# Result_FinancialStatement NetSales                       9.60224e+06
# Result_FinancialStatement OperatingIncome                2.35393e+06
# Result_FinancialStatement OrdinaryIncome                  1.6913e+06
# Result_FinancialStatement NetIncome                       1.4112e+06
# Result_FinancialStatement TotalAssets                    3.60965e+07
# Result_FinancialStatement NetAssets                       9.0092e+06
# Result_FinancialStatement CashFlowsFromOperatin...       1.17186e+06
# Result_FinancialStatement CashFlowsFromFinancin...       2.20229e+06
# Result_FinancialStatement CashFlowsFromInvestin...      -2.90802e+06
# Forecast_FinancialStatement AccountingStandard                   NaN
# ...
# Forecast_FinancialStatement NetSales                             NaN
# Forecast_FinancialStatement OperatingIncome                      NaN
# Forecast_FinancialStatement OrdinaryIncome                       NaN
# Forecast_FinancialStatement NetIncome                            NaN
# Result_Dividend FiscalPeriodEnd                              2017/09
# ...                                                              ...
# 25 windows volatility  10 mean                              0.014151
# 25 windows volatility  20 mean                             0.0143269
# 25 windows volatility  40 mean                             0.0136275
# 75 windows volatility  10 mean                             0.0145231
# 75 windows volatility  20 mean                             0.0138719
# 75 windows volatility  40 mean                              0.012956
# 5 windows volatility  10 mean diff                          0.104984
# 5 windows volatility  20 mean diff                        -0.0451252
# 5 windows volatility  40 mean diff                          0.682152
# 25 windows volatility  10 mean diff                       -0.0226203
# 25 windows volatility  20 mean diff                         0.108193
# 25 windows volatility  40 mean diff                         0.304928
# 75 windows volatility  10 mean diff                        0.0869222
# 75 windows volatility  20 mean diff                         0.179853
# 75 windows volatility  40 mean diff                         0.126341
# macd                                                         85.0905
# macd_signal                                                  129.959
# macd_hist                                                   -44.8687
# macd_hist_signal                                                  -1
# macd_cross_signal                                                  1
# macd_cross_sign_20                                                -1
# macd_cross_sign_10                                                -1
# macd_cross_sign_5                                                 -1
# slow%k                                                       43.8861
# slow%d                                                       48.0551
# stocas_hist                                                 -4.16899
# stocas_cross_signal                                                1
# stocas_hist_signal                                                -1
# stocas_cross_sign_5                                               -0
# code                                                            9984
#
#                                                           2018-11-05  \
# base_date                                                 2018/11/05
# Local Code                                                      9984
# Result_FinancialStatement AccountingStandard        ConsolidatedIFRS
# Result_FinancialStatement FiscalPeriodEnd                    2018/09
# Result_FinancialStatement ReportType                              Q2
# Result_FinancialStatement FiscalYear                            2019
# Result_FinancialStatement ModifyDate                      2018/11/05
# Result_FinancialStatement CompanyType                             GB
# Result_FinancialStatement ChangeOfFiscalYearEnd                False
# Result_FinancialStatement NetSales                       4.65385e+06
# Result_FinancialStatement OperatingIncome                1.42072e+06
# Result_FinancialStatement OrdinaryIncome                 1.40209e+06
# Result_FinancialStatement NetIncome                           840103
# Result_FinancialStatement TotalAssets                    3.38076e+07
# Result_FinancialStatement NetAssets                      7.34314e+06
# Result_FinancialStatement CashFlowsFromOperatin...               NaN
# Result_FinancialStatement CashFlowsFromFinancin...               NaN
# Result_FinancialStatement CashFlowsFromInvestin...               NaN
# Forecast_FinancialStatement AccountingStandard                   NaN
# Forecast_FinancialStatement FiscalPeriodEnd                      NaN
# Forecast_FinancialStatement ReportType                           NaN
# Forecast_FinancialStatement FiscalYear                           NaN
# Forecast_FinancialStatement ModifyDate                           NaN
# Forecast_FinancialStatement CompanyType                          NaN
# Forecast_FinancialStatement ChangeOfFiscalYearEnd                NaN
# Forecast_FinancialStatement NetSales                             NaN
# Forecast_FinancialStatement OperatingIncome                      NaN
# Forecast_FinancialStatement OrdinaryIncome                       NaN
# Forecast_FinancialStatement NetIncome                            NaN
# Result_Dividend FiscalPeriodEnd                              2018/09
# ...                                                              ...
# 25 windows volatility  10 mean                              0.034752
# 25 windows volatility  20 mean                             0.0326472
# 25 windows volatility  40 mean                              0.026146
# 75 windows volatility  10 mean                             0.0295691
# 75 windows volatility  20 mean                             0.0274378
# 75 windows volatility  40 mean                             0.0247711
# 5 windows volatility  10 mean diff                        -0.0630743
# 5 windows volatility  20 mean diff                           0.62629
# 5 windows volatility  40 mean diff                           1.13245
# 25 windows volatility  10 mean diff                           0.2722
# 25 windows volatility  20 mean diff                         0.661875
# 25 windows volatility  40 mean diff                         0.329476
# 75 windows volatility  10 mean diff                         0.106257
# 75 windows volatility  20 mean diff                         0.144553
# 75 windows volatility  40 mean diff                         0.119316
# macd                                                        -242.109
# macd_signal                                                 -281.173
# macd_hist                                                    39.0644
# macd_hist_signal                                                   1
# macd_cross_signal                                                  1
# macd_cross_sign_20                                                 1
# macd_cross_sign_10                                                 1
# macd_cross_sign_5                                                  1
# slow%k                                                       18.6036
# slow%d                                                       17.5646
# stocas_hist                                                  1.03905
# stocas_cross_signal                                                1
# stocas_hist_signal                                                 1
# stocas_cross_sign_5                                                1
# code                                                            9984
#
#                                                           2019-11-06  \
# base_date                                                 2019/11/06
# Local Code                                                      9984
# Result_FinancialStatement AccountingStandard        ConsolidatedIFRS
# Result_FinancialStatement FiscalPeriodEnd                    2019/09
# Result_FinancialStatement ReportType                              Q2
# Result_FinancialStatement FiscalYear                            2020
# Result_FinancialStatement ModifyDate                      2019/11/06
# Result_FinancialStatement CompanyType                             GB
# Result_FinancialStatement ChangeOfFiscalYearEnd                False
# Result_FinancialStatement NetSales                       4.65172e+06
# Result_FinancialStatement OperatingIncome                     -15552
# Result_FinancialStatement OrdinaryIncome                  1.1169e+06
# Result_FinancialStatement NetIncome                           421552
# Result_FinancialStatement TotalAssets                    3.68487e+07
# Result_FinancialStatement NetAssets                      8.62363e+06
# Result_FinancialStatement CashFlowsFromOperatin...               NaN
# Result_FinancialStatement CashFlowsFromFinancin...               NaN
# Result_FinancialStatement CashFlowsFromInvestin...               NaN
# Forecast_FinancialStatement AccountingStandard                   NaN
# Forecast_FinancialStatement FiscalPeriodEnd                      NaN
# Forecast_FinancialStatement ReportType                           NaN
# Forecast_FinancialStatement FiscalYear                           NaN
# Forecast_FinancialStatement ModifyDate                           NaN
# Forecast_FinancialStatement CompanyType                          NaN
# Forecast_FinancialStatement ChangeOfFiscalYearEnd                NaN
# Forecast_FinancialStatement NetSales                             NaN
# Forecast_FinancialStatement OperatingIncome                      NaN
# Forecast_FinancialStatement OrdinaryIncome                       NaN
# Forecast_FinancialStatement NetIncome                            NaN
# Result_Dividend FiscalPeriodEnd                              2019/09
# ...                                                              ...
# 25 windows volatility  10 mean                             0.0165209
# 25 windows volatility  20 mean                             0.0165444
# 25 windows volatility  40 mean                             0.0176877
# 75 windows volatility  10 mean                             0.0174837
# 75 windows volatility  20 mean                             0.0176439
# 75 windows volatility  40 mean                             0.0189289
# 5 windows volatility  10 mean diff                          0.261522
# 5 windows volatility  20 mean diff                         0.0424508
# 5 windows volatility  40 mean diff                         -0.064729
# 25 windows volatility  10 mean diff                       -0.0544498
# 25 windows volatility  20 mean diff                        -0.121421
# 25 windows volatility  40 mean diff                          -0.2375
# 75 windows volatility  10 mean diff                       -0.0689434
# 75 windows volatility  20 mean diff                        -0.121573
# 75 windows volatility  40 mean diff                          -0.1743
# macd                                                         1.70952
# macd_signal                                                 -41.6704
# macd_hist                                                    43.3799
# macd_hist_signal                                                   1
# macd_cross_signal                                                  1
# macd_cross_sign_20                                                 1
# macd_cross_sign_10                                                 0
# macd_cross_sign_5                                                  0
# slow%k                                                       87.6788
# slow%d                                                       70.3704
# stocas_hist                                                  17.3084
# stocas_cross_signal                                                1
# stocas_hist_signal                                                 1
# stocas_cross_sign_5                                                0
# code                                                            9984
#
#                                                           2020-11-09
# base_date                                                 2020/11/09
# Local Code                                                      9984
# Result_FinancialStatement AccountingStandard        ConsolidatedIFRS
# Result_FinancialStatement FiscalPeriodEnd                    2020/09
# Result_FinancialStatement ReportType                              Q2
# Result_FinancialStatement FiscalYear                            2021
# Result_FinancialStatement ModifyDate                      2020/11/09
# Result_FinancialStatement CompanyType                             GB
# Result_FinancialStatement ChangeOfFiscalYearEnd                False
# Result_FinancialStatement NetSales                       2.63053e+06
# Result_FinancialStatement OperatingIncome                        NaN
# Result_FinancialStatement OrdinaryIncome                 1.44147e+06
# Result_FinancialStatement NetIncome                      1.88321e+06
# Result_FinancialStatement TotalAssets                    3.56482e+07
# Result_FinancialStatement NetAssets                      8.42060e+06
# Result_FinancialStatement CashFlowsFromOperatin...               NaN
# Result_FinancialStatement CashFlowsFromFinancin...               NaN
# Result_FinancialStatement CashFlowsFromInvestin...               NaN
# Forecast_FinancialStatement AccountingStandard                   NaN
# Forecast_FinancialStatement FiscalPeriodEnd                      NaN
# Forecast_FinancialStatement ReportType                           NaN
# Forecast_FinancialStatement FiscalYear                           NaN
# Forecast_FinancialStatement ModifyDate                           NaN
# Forecast_FinancialStatement CompanyType                          NaN
# Forecast_FinancialStatement ChangeOfFiscalYearEnd                NaN
# Forecast_FinancialStatement NetSales                             NaN
# Forecast_FinancialStatement OperatingIncome                      NaN
# Forecast_FinancialStatement OrdinaryIncome                       NaN
# Forecast_FinancialStatement NetIncome                            NaN
# Result_Dividend FiscalPeriodEnd                              2020/09
# ...                                                              ...
# 25 windows volatility  10 mean                             0.0188367
# 25 windows volatility  20 mean                             0.0203592
# 25 windows volatility  40 mean                             0.0264685
# 75 windows volatility  10 mean                             0.0266081
# 75 windows volatility  20 mean                             0.0272582
# 75 windows volatility  40 mean                             0.0281985
# 5 windows volatility  10 mean diff                         0.0323443
# 5 windows volatility  20 mean diff                         -0.251568
# 5 windows volatility  40 mean diff                         -0.263624
# 25 windows volatility  10 mean diff                        -0.252487
# 25 windows volatility  20 mean diff                        -0.375061
# 25 windows volatility  40 mean diff                        -0.203822
# 75 windows volatility  10 mean diff                       -0.0286802
# 75 windows volatility  20 mean diff                      -0.00102124
# 75 windows volatility  40 mean diff                          0.11853
# macd                                                        -66.3356
# macd_signal                                                 -6.10311
# macd_hist                                                   -60.2325
# macd_hist_signal                                                  -1
# macd_cross_signal                                                  1
# macd_cross_sign_20                                                -1
# macd_cross_sign_10                                                -0
# macd_cross_sign_5                                                 -0
# slow%k                                                       54.7344
# slow%d                                                       31.6753
# stocas_hist                                                  23.0591
# stocas_cross_signal                                                1
# stocas_hist_signal                                                 1
# stocas_cross_sign_5                                                0
# code                                                            9984
#
# [91 rows x 20 columns]
